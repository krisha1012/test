# %% [markdown]
# Question – 1
# Display the data types of each column using the function dtypes, then take a screenshot and submit it, include your code in the image.

# %% [markdown]
# ![image.png](attachment:64c3381c-37da-4ce2-b31a-2e8099e9a42d.png)![image.png](attachment:74f227cc-3b93-4c62-aac6-b87c34410fdf.png)

# %% [markdown]
# Question 2
# Drop the columns "id" and "Unnamed: 0" from axis 1 using the method drop(), then use the method describe() to obtain a statistical summary of the data. Take a screenshot and submit it, make sure the inplace parameter is set to True

# %% [markdown]
# ![image.png](attachment:635c1034-9ce3-464e-9c60-55f505382577.png)

# %% [markdown]
# Question 3
# Use the method value_counts to count the number of houses with unique floor values, use the method .to_frame() to convert it to a dataframe.

# %% [markdown]
# ![image.png](attachment:52499bf5-0a73-4d92-9e23-8bec0dfcbe18.png)

# %% [markdown]
# Question 4
# Use the function boxplot in the seaborn library to determine whether houses with a waterfront view or without a waterfront view have more price outliers.

# %% [markdown]
# ![image.png](attachment:da3b3ca7-24c4-417b-8bc3-008eb4db31a6.png)
# ![image.png](attachment:4fb7c771-65e8-4e4b-85f5-b56942e67e63.png)

# %% [markdown]
# Question 5
# Use the function regplot in the seaborn library to determine if the feature sqft_above is negatively or positively correlated with price.

# %% [markdown]
# ![image.png](attachment:50007356-a0fb-416c-be73-60ba3b2b99dd.png)
# ![image.png](attachment:81302ac6-6efd-4797-8def-087232686e5a.png)

# %% [markdown]
# Question 6
# Fit a linear regression model to predict the 'price' using the feature 'sqft_living' then calculate the R^2. Take a screenshot of your code and the value of the R^2.

# %% [markdown]
# ![image.png](attachment:8a8c89ec-cdc7-48f3-b9a6-32d87072eaa0.png)

# %% [markdown]
# Question 7
# Fit a linear regression model to predict the 'price' using the list of features:
#
# ["floors", "waterfront","lat" ,"bedrooms" ,"sqft_basement" ,"view" ,"bathrooms","sqft_living15","sqft_above","grade","sqft_living"]
# features =["floors", "waterfront","lat" ,"bedrooms" ,"sqft_basement" ,"view" ,"bathrooms","sqft_living15","sqft_above","grade","sqft_living"]
# Then calculate the R^2. Take a screenshot of your code.

# %% [markdown]
# ![image.png](attachment:aef75699-c1ee-4974-af6b-a46a4578a537.png)

# %% [markdown]
# Question 8
# Use the list to create a pipeline object to predict the 'price', fit the object using the features in the list features, and calculate the R^2.

# %% [markdown]
# ![image.png](attachment:7378195c-0a23-4d9a-ae85-b086cf22dce2.png)

# %% [markdown]
# Question 9
# Create and fit a Ridge regression object using the training data, set the regularization parameter to 0.1, and calculate the R^2 using the test data.

# %% [markdown]
# ![image.png](attachment:ff294c3e-3c81-4d5e-97b7-d94169de6269.png)

# %% [markdown]
# Question 10
# Perform a second order polynomial transform on both the training data and testing data. Create and fit a Ridge regression object using the training data, set the regularisation parameter to 0.1, and calculate the R^2 utilising the test data provided. Take a screenshot of your code and the R^2.

# %% [markdown]
# ![image.png](attachment:249f8462-b87f-4a38-9fa9-323dc777c124.png)
